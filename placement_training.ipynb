# %% [markdown]
# <a href="https://colab.research.google.com/github/renjithr2804/placement-training/blob/main/placement_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter n:"))
k=int(input("Enter k:"))
j=int(input("Enter j:"))
m=int(input("Enter m:"))
p=int(input("Enter p:"))
if(k==0 or j==0):
  print("INVALID INPUT")
else:
  n=n-(m//k+p//j)
  if(m%k!=0 or p%k!=0):
    n=n-1
  print("No 1of monkeys in tree:",n)

# %%
a=int(input("enter 1st no:"))
b=int(input("enter 2nd no:"))
print("using temp")
temp=a
a=b
b=temp
print("a=",a)
print("b=",b)

# %%
a=int(input("enter 1st no:"))
b=int(input("enter 2nd no:"))
print("using ,")
a,b=b,a
print(a,b)

# %%
a=int(input("enter 1st no:"))
b=int(input("enter 2nd no:"))
print("using + and -")
a=a+b
b=a-b
a=a-b
print(a,b)

# %%
a=int(input("enter 1st no:"))
b=int(input("enter 2nd no:"))
print("using ^")
a=a^b
b=a^b
a=a^b
print(a,b)

# %%
N=10
K=5
C=1
R=N
while(C==1):
  M=int(input("Enter amout of candies needed:"))
  if(M>N):
    print("invalid")
  else:
    R=R-M
    if(R<=K):
      R=N
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))

# %%
a=int(input("Enter The Number of list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements in the list:"))
  list.append(b)
print("List:",list)

# %%
num=[]
total=int(input("enter the total no of elements:"))
for i in range(total):
  numbers=int(input("enter the number:"))
  num.append(numbers)
largest=max(num)
print(num)
print("largest element is",largest)

# %%
num=[]
total=int(input("enter the total no of elements:"))
for i in range(total):
  numbers=int(input("enter the number:"))
  num.append(numbers)
smallest=min(num)
print(num)
print("smallestelement is",smallest)

# %%
num=[]
total=int(input("enter the total no of elements:"))
for i in range(total):
  numbers=int(input("enter the number:"))
  num.append(numbers)
print(num)
num.reverse()
print("reverse list is",num)

# %%
num=[]
total=int(input("enter the total no of elements:"))
for i in range(total):
  numbers=int(input("enter the number:"))
  num.append(numbers)
print(num)
c=sum(num)
print("sum of elements is",c)

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
k=int(input("Enter an element to be searched:"))
if k in list:
    print("Element exist!")
else:
    print("Element not exist!")

# %%
list=[]
n=int(input("Enter list size:"))
for i in range(n):
  b=int(input("enter elements:"))
  list.append(b)
c=int(input("Enter the element to be found="))
s=0
if c in list:
  for i in list:
    if c==i:
      s=s+1
  print("Found",s,"times")
else:
  print("Not found")

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements:"))
  list.append(b)
list.sort()
print("Sorted array:",list)

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
list.sort()
print(list)
print("Second largest element is:",list[-2])

# %%
n=int(input("Enter the no. of elements: "))
a=[]
for i in range(n):
  a.append(int(input("Enter the element: ")))
print("List=",a)
n=[]
for i in a:
  if i not in n:
    n.append(i)
print("Updated list=",n)

# %%
i = map(int, input("Enter elements: ").split())
print(list(i))

# %%
arr =[10,20,30,40,50]
print(arr[1:4:2])
print(arr[:3])
print(arr[2:])
print(arr[::-1])

# %%
r = int(input("Enter number of rats: "))
unit = int(input("Enter amount of food each rat eats: "))
n = int(input("Enter number of houses: "))
arr = list(map(int, input("Enter food in each house: ").split()))
if arr is None:
    print(-1)
else:
    required = r * unit
    total = 0
    houses = 0
    for i in range(n):
        total = total + arr[i]
        houses = houses + 1
        if total >= required:
            break
    if total < required:
        print(0)
    else:
        print("Minimum number of houses:", houses)
# Out:
# Enter number of rats: 7
# Enter amount of food each rat eats: 2
# Enter number of houses: 14
# Enter food in each house: 2 8 3 5 7 4 1 2
# Minimum number of houses: 4
