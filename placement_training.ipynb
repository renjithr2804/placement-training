# %% [markdown]
# <a href="https://colab.research.google.com/github/renjithr2804/placement-training/blob/main/placement_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter n:"))
k=int(input("Enter k:"))
j=int(input("Enter j:"))
m=int(input("Enter m:"))
p=int(input("Enter p:"))
if(k==0 or j==0):
  print("INVALID INPUT")
else:
  n=n-(m//k+p//j)
  if(m%k!=0 or p%k!=0):
    n=n-1
  print("No 1of monkeys in tree:",n)
# Out:
# Enter n:20
# Enter k:2
# Enter j:3
# Enter m:12
# Enter p:12
# No 1of monkeys in tree: 10

# %%
a=int(input("enter 1st no:"))
b=int(input("enter 2nd no:"))
print("using temp")
temp=a
a=b
b=temp
print("a=",a)
print("b=",b)
# Out:
# enter 1st no:10
# enter 2nd no:5
# using temp
# a= 5
# b= 10

# %%
a=int(input("enter 1st no:"))
b=int(input("enter 2nd no:"))
print("using ,")
a,b=b,a
print(a,b)
# Out:
# enter 1st no:6
# enter 2nd no:5
# using ,
# 5 6

# %%
a=int(input("enter 1st no:"))
b=int(input("enter 2nd no:"))
print("using + and -")
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# enter 1st no:4
# enter 2nd no:8
# using + and -
# 8 4

# %%
a=int(input("enter 1st no:"))
b=int(input("enter 2nd no:"))
print("using ^")
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# enter 1st no:3
# enter 2nd no:6
# using ^
# 6 3

# %%
N=10
K=5
C=1
R=N
while(C==1):
  M=int(input("Enter amout of candies needed:"))
  if(M>N):
    print("invalid")
  else:
    R=R-M
    if(R<=K):
      R=N
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))
# Out:
# Enter amout of candies needed:3
# SOLD= 3
# Remaining= 7
# DO you want to continue(1or0):1
